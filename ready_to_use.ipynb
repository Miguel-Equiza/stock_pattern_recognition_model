# %% [markdown]
# ## how to use the model

# %%
from popping_model_logic import *
candle_types = ['doji',
       'o_marubozu', 'gravestone', 'dragonfly_doji', 'hammer', 'c_marubozu',
       'bear_engulfing', 'bull_engulfing', 'tweezer_bottom', 'tweezer_top',
       'morning_star', 'evening_star', 'three_inside_up', 'three_inside_down',
       'three_black_crows', 'three_white_soldiers']

# %% [markdown]
# here: https://investexcel.net/all-yahoo-finance-stock-tickers/ you can see a list of all the ticker names, but the majority of them are the same as the stock exchange name

# %%
plotting(ticker = "GOOGL", start_date = "2019-11-03", end_date = "2020-06-06", with_candle = True, cdle_patterns = ['doji', 'o_marubozu'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-55-cc357fa118e6>:28: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
